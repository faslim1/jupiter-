# %% [markdown]
# Pie Chart

# %%
import matplotlib.pyplot as plt
sizes =[40,30,20,10]
categ = ['A','B','C','D']

# %%
sizes = [40,30,20,10]
categ = ['A','B','C','D']
explode[0,0.2,2,0,0]

plt.pie(sizes, labels = labels , explode = explode, autopct = '1.1f%%' , wedgeprops = {'edgecolour':'black','width':0.6})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 sizes = [40,30,20,10]
#       2 categ = ['A','B','C','D']
# ----> 3 explode[0,0.2,2,0,0]
#       4
#       5 plt.pie(sizes, labels = labels , explode = explode, autopct = '1.1f%%' , wedgeprops = {'edgecolour':'black','width':0.6})
#       6 plt.show()
#
# NameError: name 'explode' is not defined

# %%
sizes = [40,30,20,10]
labels = ['A','B','C','D']
explode = [0,0.2,0,0]

plt.pie(
